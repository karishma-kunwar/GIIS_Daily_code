# %%
import pandas as pd
df = pd.read_csv("pieChart.csv")
#data for pie
data=df.iloc[:, 1].to_list()
data1= df.iloc[:, 2].to_list()
data2=df.iloc[:, 3].to_list()
data3=df.iloc[:, 4].to_list()

#data for bar
df2=pd.read_csv("barChart.csv")

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(
    rows=2, cols=4,row_heights=[0.4,0.6],
    specs=[[{"type": "domain"}, {"type": "domain"},{"type": "domain"},{"type": "domain"}],
           [ {"type": "xy"},{"type": "xy"},{"type": "xy"},{"type": "xy"}]],shared_yaxes=True,vertical_spacing=0.00,
                        horizontal_spacing=0.05
)

colors1= ['#E72863','#9e9e9e']
labels=df.iloc[:, 0].to_list()
#single row pie chart 
lables=df.iloc[:, 0].to_list()
fig.add_trace(
    go.Pie(values = data, 
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textfont=dict(
                        family="sans serif",
                        size=12,   
                        )),
            row=1, col=1),



fig.add_trace( go.Pie(values = data1,
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textfont=dict(
                        family="sans serif",
                        size=12,   
                        )),
              row=1, col=2),
              
              
fig.add_trace( go.Pie(values = data2,
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        #textposition= "inside",
                        textfont=dict(
                        family="Gill Sans",
                        size=12,   
                        )),
              row=1, col=3),
              
              
fig.add_trace( go.Pie(values = data3,
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        #textposition= "inside",
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textfont=dict(
                        family="sans serif",
                        size=12,   
                        )),
              row=1, col=4),
    
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=4) 
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=3)  
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=2)  
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=1)

fig.update_layout(plot_bgcolor='#ff0000')
#adding the bar chart in the figure
#****************************************************************************************************************************#
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['women%-M'],
    customdata = df2['महिला-M'].to_numpy(),
    hovertemplate = "%{y}<br>महिला %{x}%<br> (%{customdata})<br><extra></extra>",
    orientation='h',
    marker=dict(
        color='#E72863',
        line=dict(color='#FFFFFF')
    )
),row=2,col=1)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['men%-M'],
    customdata = df2['पुरुष-M'].to_numpy(),
    hovertemplate = "%{y}<br>पुरुष %{x}%<br> (%{customdata})<br><extra></extra>",
    text=df2['women%-M'].to_list(),
    texttemplate = "%{text}%",
    textfont = { 'size':14, 'color':"white"},
    textposition="inside",
    orientation='h',
    marker=dict(
        color='#9e9e9e',
        line=dict(color='#FFFFFF')
    )
),row=2,col=1)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['women%-DM'],
    customdata = df2['महिला-DM'].to_numpy(),
    hovertemplate = "%{y}<br>महिला %{x}%<br> (%{customdata})<br><extra></extra>",
    text=df2['women%-DM'].to_list(),
    texttemplate = "%{text}%",
    textfont = { 'size':14, 'color':"white"},
    textposition="outside",
    orientation='h',
    marker=dict(
        color='#E72863',
        line=dict(color='#FFFFFF')
    )
),row=2,col=2)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['men%-DM'],
    customdata = df2['पुरुष-DM'].to_numpy(),
    hovertemplate = "%{y}<br>पुरुष %{x}%<br> (%{customdata})<br><extra></extra>",
    orientation='h',
    marker=dict(
        color='#9e9e9e',
        line=dict(color='#FFFFFF')
    )
),row=2,col=2)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['women%-WP'],
    customdata = df2['महिला-DM'].to_numpy(),
    hovertemplate = "%{y}<br>महिला %{x}%<br> (%{customdata})<br><extra></extra>",
    orientation='h',
    marker=dict(
        color='#E72863',
        line=dict(color='#FFFFFF')
    )
),row=2,col=3)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['men%-WP'],
    text=df2['women%-WP'].to_list(),
    texttemplate = "%{text}%",
    customdata = df2['पुरुष-WP'].to_numpy(),
    hovertemplate = "%{y}<br>पुरुष %{x}%<br> (%{customdata})<br><extra></extra>",
    textfont = { 'size':14, 'color':"white"},
    textposition="auto",
    orientation='h',
    marker=dict(
        color='#9e9e9e',
        line=dict(color='#FFFFFF')
    )
),row=2,col=3)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['women%-WM'],
    customdata = df2['महिला-WM'].to_numpy(),
    hovertemplate = "%{y}<br>महिला %{x}%<br> (%{customdata})<br><extra></extra>",
    orientation='h',
    marker=dict(
        color='#E72863',
        line=dict(color='#FFFFFF')
    )
),row=2,col=4)
fig.add_trace(go.Bar(
    y=df2["पार्टी"],
    x=df2['men%-WM'],
    customdata = df2['पुरुष-WM'].to_numpy(),
    hovertemplate = "%{y}<br>पुरुष %{x}%<br> (%{customdata})<br><extra></extra>",
    text=df2['women%-WP'].to_list(),
    textfont = { 'size':14, 'color':"white"},
    texttemplate = "%{text}%",
    textposition="auto",
    orientation='h',
    marker=dict(
        color='#9e9e9e',
        line=dict(color='#FFFFFF')
    )
),row=2,col=4)
fig.update_traces(insidetextanchor="start", selector=dict(type='bar'))
fig.update_layout(
    paper_bgcolor='rgba(255,0,0,0)',
    plot_bgcolor='rgba(0,0,255,0)',
#     title={
#         'y':0.96,
#         'x':0.5,
#         'xanchor': 'center',
#         'yanchor': 'top'},
    barmode='stack',
    uniformtext_minsize=10,
     showlegend=False)
#fig.update_traces(textposition="outside",row=2,col=1)


#fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide')
#fig.update_traces(textfont_size=33, textangle=0, textposition="outside", cliponaxis=False,row=2,col=1)

fig.update_layout(
    paper_bgcolor='#ffffff',
    plot_bgcolor='#ffffff',
#     title={
#         'y':0.96,
#         'x':0.5,
#         'xanchor': 'center',
#         'yanchor': 'top'},    
    barmode='stack',showlegend=False)
3
fig.add_shape(type='line',
                x0=7,
                y0=-0.75,
                x1=7,
                y1=9.75,
                line=dict(color='#FF9500',width=1.5),
#                 xref='x',
#                 yref='y',
              row=2,col=1,layer='below'
)
fig.add_shape(type='line',
                x0=73,
                y0=-0.75,
                x1=73,
                y1=9.75,
                line=dict(color='#FF9500',width=1.5),
#                 xref='x',
#                 yref='y',
              row=2,col=2,layer='below'
)
fig.add_shape(type='line',
                x0=3,
                y0=-0.75,
                x1=3,
                y1=9.75,
                 line=dict(color='#FF9500',width=1.5),
#                 xref='x',
#                 yref='y',
              row=2,col=3,layer='below'
)
fig.add_shape(type='line',
                x0=5,
                y0=-0.75,
                x1=5,
                y1=9.75,
                 line=dict(color='#FF9500',width=1.5),
#                 xref='x',
#                 yref='y',
              row=2,col=4,layer='below'
)

#*****************************************************************************************************************************#
#updates in the pie 


fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.15,
    y=1.08,
    font=dict(
                color="black",
                size=19
            ),
    text="<b>अध्यक्ष/प्रमुख<b>",
     showarrow=False

)

fig.add_annotation(
    xref="x domain",
    yref="y domain",
     font=dict(
                color="black",
                size=19
            ),
    x=2.23,
        y=1.08,
    text="<b>उपाध्यक्ष/उपप्रमुख<b>",
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=3.19,
        y=1.08,
     font=dict(
                color="black",
                size=19
            ),
    text="<b>वडा अध्यक्ष<b>",
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=4.39,
        y=1.08,
     font=dict(
                color="black",
                size=19
            ),
    text="<b>वडा सदस्य<b>",
     showarrow=False

)

#adding the data in the center of the hole 
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.51,
    y=1.362,
    text="6.7%",
     font=dict(
                color="black",
                size=17
            ),
     showarrow=False

)

fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=1.9,
      y=1.362,
    text="73.2%",
     font=dict(
                color="black",
                size=17
            ),
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=3.105,
      y=1.362,
    text="3.7%",
     font=dict(
                color="black",
                size=17
            ),
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=4.35, 
    y=1.362,
    font=dict(
                color="black",
                size=17
            ),
    
    text="4.7%",
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=-0.1, 
    y=-0.1,
    font=dict(
                color="#888888",
                size=14
            ),
    
    text="स्रोत: निर्वाचन आयोग    |    स्थानीय तह निर्वाचन २०७९    |    © अनलाइनखबर",
     showarrow=False

)
#******************************************** adding the rastriya ausat******************************
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=4.68, 
    y=-0.01,
    font=dict(
                color="black",
                size=14
            ),
    
    text="राष्ट्रिय औसत",
     showarrow=False

)
fig.add_shape(type='line',
                x0=52,
                y0=-1.2,
                x1=52,
                y1=-1.4,
             
                 line=dict(color='#FF9500',width=8),
#                 xref='x',
#                 yref='y',
              row=2,col=4
              
)

#*****************************************************************************************************************************#

#adding the tittle
fig.update_layout(
    title={
        'text': "<b>स्थानीय निर्वाचनको उम्मेदवारीमा महिलाहरुको प्रतिनिधित्व - २०७४</b>",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
         
    },
    title_font_size=25,
     font=dict(
                color="black",
                size=17
            ),
    images=[dict(
        source='https://i.ibb.co/Pwr8Bvp/ok-logo.png',
        xref="paper", yref="paper",
        x=1.1,  y=-0.1,
        sizex=0.1, sizey=0.1,
        xanchor="right",yanchor="bottom",
        layer = "below"
         
        
      )],
)
config={"modeBarButtonsToRemove": ['select2d','zoomIn2d','zoomOut2d','zoom2d','pan2d','lasso2d','autoScale2d','resetScale2d','resetScale2d'],'displaylogo': False}

fig.update_layout(height=800,width=1000)
fig.update_xaxes(showticklabels=False)
fig.update_layout(font_family="sans-serif")

fig.write_html("pie_bar_April_29_up.html",config= config)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Reading the agegroup data for each party

df3 = pd.read_csv("agewise.csv")

df31 = df3.iloc[:,1].tolist()
df32 = df3.iloc[:,2].tolist()
df33 = df3.iloc[:,3].tolist()
df34= df3.iloc[:,4].tolist()

# %%
# creating subplots in plotly here we will create 4 subplots with 

fig = make_subplots(
            rows=1, cols=4,specs=[[{"type": "domain"}, {"type": "domain"},{"type": "domain"}, {"type": "domain"}]],
             #subplot_titles=("अध्यक्ष","उपाध्यक्ष","वडा अध्यक्ष","सदस्य")
        )

colors1= ['#57AF9F','#F2BA43','#CAEEC2']
labels=df3.iloc[:, 0].to_list()
#single row pie chart 
lables=df.iloc[:, 0].to_list()
fig.add_trace(
    go.Pie(values = df31, 
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textposition= "inside",
                        textfont=dict(
                        family="sans serif",
                        size=12,   
                        )),
            row=1, col=1),



fig.add_trace( go.Pie(values = df32,
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textposition= "inside",
                        textfont=dict(
                        family="sans serif",
                        size=12,   
                        )),
              row=1, col=2),
              
              
fig.add_trace( go.Pie(values = df33,
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textposition= "inside",
                        textfont=dict(
                        family="Gill Sans",
                        size=12,   
                        )),
              row=1, col=3),
              
              
fig.add_trace( go.Pie(values = df34,
                        labels = labels, hole = 0.55,                          
                        marker_colors = colors1,
                        #textposition= "inside",
                        name =" ",
                        direction ='counterclockwise',
                        sort=False,
                        textposition= "inside",
                        textfont=dict(
                        family="sans serif",
                        size=12,   
                        )),
              row=1, col=4),
    
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=4) 
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=3)  
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=2)  
fig.update_traces(textinfo='none', marker=dict(colors=colors1, line=dict(color='#FFFFFF', width=1)),row=1, col=1)

fig.update_layout(plot_bgcolor='#ff0000')


#******************************************** adding the rastriya ausat******************************


#adding the tittle
fig.update_layout(
    title={
        'text': "<b>स्थानीय निर्वाचनको उम्मेदवारीमा महिलाहरुको प्रतिनिधित्व - २०७४</b>",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top',
         
    },
    title_font_size=25,
     font=dict(
                color="black",
                size=17
            )
     
)

fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.05,
    y=1,
    font=dict(
                color="black",
                size=19
            ),
    text="<b>अध्यक्ष/प्रमुख<b>",
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
     font=dict(
                color="black",
                size=19
            ),
    x=0.30,
        y=1,
    text="<b>उपाध्यक्ष/उपप्रमुख<b>",
     showarrow=False

)

fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.63,
        y=1,
     font=dict(
                color="black",
                size=19
            ),
    text="<b>वडा अध्यक्ष<b>",
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.93,
        y=1,
     font=dict(
                color="black",
                size=19
            ),
    text="<b>वडा सदस्य<b>",
     showarrow=False

)

#adding the data in the center of the hole 
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.05,
    y=1.362,
    text="6.7%",
     font=dict(
                color="black",
                size=17
            ),
     showarrow=False

)

fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.30,
      y=1.362,
    text="73.2%",
     font=dict(
                color="black",
                size=17
            ),
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.63,
      y=1.362,
    text="3.7%",
     font=dict(
                color="black",
                size=17
            ),
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=0.93, 
    y=1.362,
    font=dict(
                color="black",
                size=17
            ),
    
    text="4.7%",
     showarrow=False

)
fig.add_annotation(
    xref="x domain",
    yref="y domain",
    x=-0.05, 
    y=-0.1,
    font=dict(
                color="#888888",
                size=14
            ),
    
    text="स्रोत: निर्वाचन आयोग    |    स्थानीय तह निर्वाचन २०७९    |    © अनलाइनखबर",
     showarrow=False

)
fig.update_layout(
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
